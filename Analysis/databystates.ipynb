# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\HP\Desktop\XAI\DATA\crop_yield.csv')

# %%
df
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 0           Arecanut       1997  Whole Year               Assam   73814.0
# 1          Arhar/Tur       1997  Kharif                   Assam    6637.0
# 2        Castor seed       1997  Kharif                   Assam     796.0
# 3           Coconut        1997  Whole Year               Assam   19656.0
# 4       Cotton(lint)       1997  Kharif                   Assam    1739.0
# ...              ...        ...          ...                ...       ...
# 19684  Small millets       1998  Kharif                Nagaland    4000.0
# 19685          Wheat       1998  Rabi                  Nagaland    1000.0
# 19686          Maize       1997  Kharif       Jammu and Kashmir  310883.0
# 19687           Rice       1997  Kharif       Jammu and Kashmir  275746.0
# 19688          Wheat       1997  Rabi         Jammu and Kashmir  239344.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide        Yield
# ...

# %%
jharkhand_crops = df[df['State'] == 'Jharkhand']

# %%
jharkhand_crops.size
# Out:
# 2700

# %%
jharkhand_crops
# Out:
#             Crop  Crop_Year       Season      State       Area  Production  \
# 8349   Arhar/Tur       2002  Rabi         Jharkhand   18045.15       30067
# 8350        Gram       2002  Rabi         Jharkhand    9748.47        8312
# 8351       Maize       2002  Autumn       Jharkhand   62780.33       74310
# 8352      Masoor       2002  Rabi         Jharkhand    3053.66        2381
# 8353      Potato       2002  Rabi         Jharkhand   12269.37       91201
# ...          ...        ...          ...        ...        ...         ...
# 16880   Soyabean       2019  Kharif       Jharkhand    1193.00        1023
# 16881  Sunflower       2019  Kharif       Jharkhand     149.00          78
# 16882  Sunflower       2019  Rabi         Jharkhand     398.00         218
# 16883       Urad       2019  Kharif       Jharkhand  128440.00      111657
# 16884      Wheat       2019  Rabi         Jharkhand  214780.00      439401
#
#        Annual_Rainfall    Fertilizer   Pesticide     Yield
# ...

# %%
jharkhand_crops = jharkhand_crops.sort_values(by='Crop_Year' , ascending=False)

# %%
jharkhand_crops
# Out:
#                     Crop  Crop_Year       Season      State       Area  \
# 16884              Wheat       2019  Rabi         Jharkhand  214780.00
# 16871         Niger seed       2019  Kharif       Jharkhand    3117.00
# 16859          Arhar/Tur       2019  Kharif       Jharkhand  230559.00
# 16860              Bajra       2019  Kharif       Jharkhand     288.00
# 16861        Castor seed       2019  Kharif       Jharkhand      58.00
# ...                  ...        ...          ...        ...        ...
# 8356   Rapeseed &Mustard       2002  Rabi         Jharkhand    4704.34
# 8357                Rice       2002  Autumn       Jharkhand  136359.61
# 8358                Rice       2002  Winter       Jharkhand  922658.68
# 8359               Wheat       2002  Rabi         Jharkhand   57203.69
# 8349           Arhar/Tur       2002  Rabi         Jharkhand   18045.15
#
#        Production  Annual_Rainfall    Fertilizer    Pesticide     Yield
# ...

# %%
jharkhand_crops['Crop'].unique()
# Out:
# array(['Wheat', 'Niger seed', 'Arhar/Tur', 'Bajra', 'Castor seed', 'Gram',
#        'Groundnut', 'Horse-gram', 'Jowar', 'Maize', 'Masoor',
#        'Moong(Green Gram)', 'Linseed', 'Other  Rabi pulses', 'Safflower',
#        'Other Kharif pulses', 'Sunflower', 'Soyabean', 'Sesamum', 'Urad',
#        'Rice', 'Rapeseed &Mustard', 'Ragi', 'Peas & beans (Pulses)',
#        'Potato', 'Onion', 'Sugarcane', 'Barley'], dtype=object)

# %%
jharkhand_crops['Annual_Rainfall'].unique()
# Out:
# array([1137.8, 1222.7, 1165.7, 1296.3, 1085.6, 1156.6, 1253.6, 1102. ,
#        1374.7,  694.6,  996.1, 1295.2, 1444.7, 1465.1,  965.2, 1149.2,
#        1258.3, 1041.2])

# %%
df.to_csv('Jharkhad_crops.csv')

# %%
df['Season'].unique()
# Out:
# array(['Whole Year ', 'Kharif     ', 'Rabi       ', 'Autumn     ',
#        'Summer     ', 'Winter     '], dtype=object)

# %%
sns.boxplot(data = df , x ='Annual_Rainfall')
# Out:
# <Axes: xlabel='Annual_Rainfall'>

# %%
sns.countplot(data=jharkhand_crops, x='Season', hue='Crop')
plt.xticks(rotation=45)  # rotate x labels if needed
plt.legend().remove()
plt.show()
