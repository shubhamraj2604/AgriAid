# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("hiramscud/rice-disease-detection-dataset-of-6000-images")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 402M/402M [00:02<00:00, 148MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/hiramscud/rice-disease-detection-dataset-of-6000-images/versions/2

# %%
import os

dataset_path = "/root/.cache/kagglehub/datasets/hiramscud/rice-disease-detection-dataset-of-6000-images/versions/2"
os.listdir(dataset_path)
# Out:
# ['images', 'data.yaml', 'labels']

# %%
# !pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
print("Ultralytics installed successfully")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics installed successfully

# %%
# !find /root/.cache/kagglehub/datasets/hiramscud -name data.yaml
# Out:
# /root/.cache/kagglehub/datasets/hiramscud/rice-disease-detection-dataset-of-6000-images/versions/2/data.yaml

# %%
# !cat /root/.cache/kagglehub/datasets/hiramscud/rice-disease-detection-dataset-of-6000-images/versions/2/data.yaml
# Out:
# path: C:/Users/HP/.cache/kagglehub/datasets/hiramscud/rice-disease-detection-dataset-of-6000-images/versions/2
#
# train: images/train
# val: images/val
# test: images/test
#
# nc: 3
# names:
#   0: Bacteria_Leaf_Blight
#   1: Brown_Spot
#   2: Leaf_smut

# %%
# !sed -i '/^path:/d' /root/.cache/kagglehub/datasets/hiramscud/rice-disease-detection-dataset-of-6000-images/versions/2/data.yaml

# %%
# !cat /root/.cache/kagglehub/datasets/hiramscud/rice-disease-detection-dataset-of-6000-images/versions/2/data.yaml
# Out:
# train: images/train
# val: images/val
# test: images/test
#
# nc: 3
# names:
#   0: Bacteria_Leaf_Blight
#   1: Brown_Spot
#   2: Leaf_smut

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/root/.cache/kagglehub/datasets/hiramscud/rice-disease-detection-dataset-of-6000-images/versions/2/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.4.0 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
runs/detect/train3/weights/best.pt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2540407372.py in <cell line: 0>()
# ----> 1 runs/detect/train3/weights/best.pt
#
# NameError: name 'runs' is not defined

# %%
# !ls /content/runs/detect/train4/weights
# Out:
# best.pt  last.pt

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train4/weights/best.pt")
model.val()
# Out:
# Ultralytics 8.4.0 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 73 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2017.3±470.1 MB/s, size: 77.9 KB)
# val: Scanning /root/.cache/kagglehub/datasets/hiramscud/rice-disease-detection-dataset-of-6000-images/versions/2/labels/val.cache... 671 images, 10 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 671/671 140.7Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 4.6it/s 9.2s
#                    all        671       2482      0.897       0.88      0.931      0.604
#   Bacteria_Leaf_Blight        282        312      0.908      0.951      0.971      0.722
#             Brown_Spot        172       1603      0.863       0.76      0.855      0.448
#              Leaf_smut        207        567      0.921      0.928      0.967      0.641
# ...

# %%
# !ls
# Out:
# sample_data
